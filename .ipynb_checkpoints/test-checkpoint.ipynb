# %%
from octokit import Octokit


octokit = Octokit(
    token='ghp_...',
    owner='piccolojnr',
    repo='resell'
)

# %%
repos = Octokit().repos.get``
repos
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\rahim\anaconda3\Lib\site-packages\octokit\base.py:98, in Base.validate_required_parameters(self, parameters, required_parameters)
#      97 try:
# ---> 98     assert required_parameter in parameters
#      99 except AssertionError:
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# OctokitParameterError                     Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 repos = Octokit().repos.list_for_user('piccolojnr')
#       2 repos
#
# File c:\Users\rahim\anaconda3\Lib\site-packages\octokit\__init__.py:38, in Octokit._create_method.<locals>._api_call(*args, **kwargs)
#      36 def _api_call(*args, **kwargs):
#      37     method_headers = kwargs.pop("headers") if kwargs.get("headers") else {}
# ---> 38     self.validate(kwargs, definition)
# ...

# %%
repos.json
# Out:
# [{'id': 895251850,
#   'node_id': 'R_kgDONVx1ig',
#   'name': 'advanced_database_project',
#   'full_name': 'piccolojnr/advanced_database_project',
#   'private': False,
#   'owner': {'login': 'piccolojnr',
#    'id': 99098839,
#    'node_id': 'U_kgDOBegg1w',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99098839?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/piccolojnr',
#    'html_url': 'https://github.com/piccolojnr',
#    'followers_url': 'https://api.github.com/users/piccolojnr/followers',
#    'following_url': 'https://api.github.com/users/piccolojnr/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/piccolojnr/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/piccolojnr/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/piccolojnr/subscriptions',
#    'organizations_url': 'https://api.github.com/users/piccolojnr/orgs',
# ...
